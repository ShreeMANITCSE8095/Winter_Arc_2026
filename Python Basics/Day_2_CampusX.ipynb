# %%
# Arithematic Operators
print(5/2)
print(5//2)
print(5**2)
print(25**(1/2))
# Out:
# 2.5
# 2
# 25
# 5.0

# %%
# Bitwise Operator
print(0b10101 & 0b11110)
print(0b111 | 0b1011)
print(1^1)
# Out:
# 20
# 15
# 0

# %%
print(~10)
# Out:
# -11

# %%
# x++ & ++x & x-- & --x are NOT used in Python
x= 2
x+= 2
print(x)
# Out:
# 4

# %%
# Membership Operators
# in/not in
print("D" in "Delhi", "B" not in "Bihar")
# Out:
# True False

# %%
print(1 in [1, 3,2, 4,5])
# Out:
# True

# %%
num= int(input())
ans= 0
while num!= 0:
    ans+= num% 10
    num//= 10
print(ans)
# Out:
#  245
# 11

# %%
age= int(input())
if age>= 18:
    print(True)
else:
    print(False)
# Out:
#  56
# True

# %%
a= int(input('A:'))
b= int(input('B:'))
c= int(input('C:'))

print(min(a, b, c))
# Out:
# A: 10
# B: 20
# C: 10
# 10

# %%
X= int(input("First Number:"))
Y= int(input("Second Number:"))

op= input("Operation:")
if op== '+':
    print(X+Y)
elif op== '-':
    print(X-Y)
elif op== '*':
    print(X*Y)
else:
    print(x/y)
# Out:
# First Number: 24
# Second Number: 6
# Operation: +
# 30

# %%
# Modules in Python
import math
math.sqrt(25)
# Out:
# 5.0

# %%
import math
math.factorial(0)
# Out:
# 1

# %%
import random
random.randint(0, 100)
# Out:
# 1

# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2026-09-03 13:09:35.091436

# %%
num= int(input("Enter a Number"))
i= 1
while i<= 10:
    print(num*i)
    i+= 1
# Out:
# Enter a Number 25
# 25
# 50
# 75
# 100
# 125
# 150
# 175
# 200
# 225
# 250

# %%
num= int(input("Enter a Number"))
for i in range(10):
    print(num*i)
# Out:
# Enter a Number 4
# 0
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36

# %%
import random
target= random.randint(1, 100)

count= 0
while True:
    count+= 1
    guess= int(input("Guess the Number:"))
    if guess== target:
        print("You Guessed it in", count, "tries")
        break
    elif guess> target:
        print("Guess is Too High")
    else:
        print("Guess is Too Low")
# Out:
# Guess is Too High
# Guess is Too High
# Guess is Too Low
# Guess is Too High
# You Guessed it in 5 tries

# %%
curr= 10000
for i in range(1, 11):
    curr= curr*1.05
    print("Year", i, ":", curr)
# Out:
# Year 1 : 10500.0
# Year 2 : 11025.0
# Year 3 : 11576.25
# Year 4 : 12155.0625
# Year 5 : 12762.815625000001
# Year 6 : 13400.956406250001
# Year 7 : 14071.004226562502
# Year 8 : 14774.554437890627
# Year 9 : 15513.28215978516
# Year 10 : 16288.946267774418
